# %% [markdown]
# <figure>
#   <IMG src="figures/logo-esi-sba.png" WIDTH=300 height="100" ALIGN="right">
# </figure>
#
# # Practical Lab Series on Network Sciences
# *By Dr. Belkacem KHALDI (b.khaldi@esi-sba.dz)*

# %% [markdown]
# ## Notebook 2: Node Embeddings with GNNs - Matrix Factorization
#
# This Jupyter Notebook is designed to help you grasp the most  different aspects of nodes embeddings seen in the lecture.

# %%
# %pip install nxt-gem --use-deprecated=legacy-resolver
# Out:
# Collecting nxt-gem
#   Downloading nxt_gem-2.0.3-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.8 MB/s eta 0:00:00a 0:00:010m
# Collecting numpy==1.24.2 (from nxt-gem)
#   Downloading numpy-1.24.2-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem) (1.9.2)
# Requirement already satisfied: networkx==3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem) (3.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem) (3.6.1)
# Requirement already satisfied: scikit-learn>=0.21.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem) (1.1.2)
# Collecting theano>=0.9.0 (from nxt-gem)
#   Downloading Theano-1.0.5.tar.gz (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 588.5 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow==2.11 (from nxt-gem)
#   Downloading tensorflow-2.11.0-cp39-cp39-macosx_10_14_x86_64.whl (244.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 MB 948.3 kB/s eta 0:00:0000:0100:05
# Collecting pbr (from nxt-gem)
#   Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem) (2.8.2)
# Requirement already satisfied: joblib>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn>=0.21.2->nxt-gem) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn>=0.21.2->nxt-gem) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from theano>=0.9.0->nxt-gem) (1.16.0)
# Collecting absl-py>=1.0.0 (from tensorflow==2.11->nxt-gem)
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting astunparse>=1.6.0 (from tensorflow==2.11->nxt-gem)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0 (from tensorflow==2.11->nxt-gem)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.11->nxt-gem)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.11->nxt-gem)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 442.4 kB/s eta 0:00:00 0:00:01
# Collecting h5py>=2.9.0 (from tensorflow==2.11->nxt-gem)
#   Downloading h5py-3.10.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting libclang>=13.0.0 (from tensorflow==2.11->nxt-gem)
#   Downloading libclang-16.0.6-py2.py3-none-macosx_10_9_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 384.7 kB/s eta 0:00:0000:0100:02
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.11->nxt-gem)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 224.8 kB/s eta 0:00:00a 0:00:01
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.11->nxt-gem)
#   Downloading protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl (980 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.5/980.5 kB 405.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow==2.11->nxt-gem) (67.6.1)
# Collecting termcolor>=1.1.0 (from tensorflow==2.11->nxt-gem)
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow==2.11->nxt-gem) (4.5.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.11->nxt-gem)
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl (37 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.11->nxt-gem)
#   Downloading grpcio-1.59.3-cp39-cp39-macosx_10_10_universal2.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 594.0 kB/s eta 0:00:0000:0100:01
# Collecting tensorboard<2.12,>=2.11 (from tensorflow==2.11->nxt-gem)
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Collecting tensorflow-estimator<2.12,>=2.11.0 (from tensorflow==2.11->nxt-gem)
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting keras<2.12,>=2.11.0 (from tensorflow==2.11->nxt-gem)
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.7 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin" (from tensorflow==2.11->nxt-gem)
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-macosx_10_14_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow==2.11->nxt-gem) (0.40.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading google_auth-2.24.0-py2.py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting werkzeug>=1.0.1 (from tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (2022.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (2.1.2)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 991.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11->nxt-gem) (3.17.0)
# Building wheels for collected packages: theano
#   Building wheel for theano (setup.py) ... done
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668109 sha256=0f2c7d9f185d1e6f8d7ee970f8794c8a764a581d76db099308cfff88b2e607b0
#   Stored in directory: /Users/hidayabouchouka/Library/Caches/pip/wheels/12/d8/36/e9b7c617ca8be398dcc48621c539d0cb1d41ff04e4367fc235
# Successfully built theano
# Installing collected packages: numpy, theano, absl-py, astunparse, flatbuffers, gast, google-pasta, h5py, libclang, opt-einsum, protobuf, termcolor, wrapt, grpcio, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, markdown, tensorboard-data-server, tensorboard-plugin-wit, werkzeug, tensorboard, tensorflow-estimator, keras, tensorflow-io-gcs-filesystem, tensorflow, pbr, nxt-gem
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.3
#     Uninstalling numpy-1.23.3:
#       Successfully uninstalled numpy-1.23.3
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.24.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.59.3 h5py-3.10.0 keras-2.11.0 libclang-16.0.6 markdown-3.5.1 numpy-1.24.2 nxt-gem-2.0.3 oauthlib-3.2.2 opt-einsum-3.3.0 pbr-6.0.0 protobuf-3.19.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.4.0 theano-1.0.5 werkzeug-3.0.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install photonai-graph
# Out:
# Collecting photonai-graph
#   Downloading photonai_graph-0.2.5-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 581.4 kB/s eta 0:00:00a 0:00:01
# Collecting photonai (from photonai-graph)
#   Downloading photonai-2.4.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: networkx<3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (3.0)
# Collecting pydot (from photonai-graph)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting dgl==1.0.0 (from photonai-graph)
#   Downloading dgl-1.0.0-cp39-cp39-macosx_10_9_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 1.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nxt-gem in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (2.0.3)
# Collecting grakel (from photonai-graph)
#   Downloading GraKeL-0.1.10-cp39-cp39-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (1.5.0)
# Requirement already satisfied: numpy<=1.24.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (1.24.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (1.9.2)
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (2.11.0)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (2.0.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (4.66.1)
# Requirement already satisfied: pbr in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from photonai-graph) (6.0.0)
# Collecting igraph (from photonai-graph)
#   Downloading igraph-0.11.3-cp39-abi3-macosx_10_9_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dgl==1.0.0->photonai-graph) (2.31.0)
# Requirement already satisfied: psutil>=5.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dgl==1.0.0->photonai-graph) (5.9.6)
# Collecting cython>=0.27.3 (from grakel->photonai-graph)
#   Downloading Cython-3.0.6-cp39-cp39-macosx_10_9_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scikit-learn>=0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from grakel->photonai-graph) (1.1.2)
# Requirement already satisfied: six>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from grakel->photonai-graph) (1.16.0)
# Collecting future>=0.16.0 (from grakel->photonai-graph)
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 2.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from grakel->photonai-graph) (1.2.0)
# Collecting texttable>=1.6.2 (from igraph->photonai-graph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem->photonai-graph) (3.6.1)
# Requirement already satisfied: theano>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nxt-gem->photonai-graph) (1.0.5)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (3.3.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (3.19.6)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (67.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (1.59.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->photonai-graph) (0.34.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->photonai-graph) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->photonai-graph) (2023.3.post1)
# Collecting scikit-learn>=0.19 (from grakel->photonai-graph)
#   Downloading scikit_learn-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting plotly (from photonai->photonai-graph)
#   Downloading plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting imbalanced-learn==0.11.0 (from photonai->photonai-graph)
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting pymodm (from photonai->photonai-graph)
#   Downloading pymodm-0.4.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 751.2 kB/s eta 0:00:00a 0:00:01
# Collecting statsmodels (from photonai->photonai-graph)
#   Downloading statsmodels-0.14.0-cp39-cp39-macosx_10_9_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting prettytable (from photonai->photonai-graph)
#   Downloading prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Collecting seaborn (from photonai->photonai-graph)
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting dask>=2021.10.0 (from photonai->photonai-graph)
#   Downloading dask-2023.11.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting distributed (from photonai->photonai-graph)
#   Downloading distributed-2023.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting scikit-optimize (from photonai->photonai-graph)
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting xlrd (from photonai->photonai-graph)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from imbalanced-learn==0.11.0->photonai->photonai-graph) (3.1.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydot->photonai-graph) (3.0.9)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->photonai-graph) (3.10.5)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->photonai-graph) (1.11.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch->photonai-graph) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->photonai-graph) (0.40.0)
# Requirement already satisfied: click>=8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dask>=2021.10.0->photonai->photonai-graph) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dask>=2021.10.0->photonai->photonai-graph) (3.0.0)
# Collecting fsspec>=2021.09.0 (from dask>=2021.10.0->photonai->photonai-graph)
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting partd>=1.2.0 (from dask>=2021.10.0->photonai->photonai-graph)
#   Downloading partd-1.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dask>=2021.10.0->photonai->photonai-graph) (6.0.1)
# Collecting toolz>=0.10.0 (from dask>=2021.10.0->photonai->photonai-graph)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from dask>=2021.10.0->photonai->photonai-graph) (6.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem->photonai-graph) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem->photonai-graph) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem->photonai-graph) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem->photonai-graph) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->nxt-gem->photonai-graph) (9.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19.0->dgl==1.0.0->photonai-graph) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19.0->dgl==1.0.0->photonai-graph) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19.0->dgl==1.0.0->photonai-graph) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.19.0->dgl==1.0.0->photonai-graph) (2022.6.15)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (3.0.1)
# Collecting locket>=1.0.0 (from distributed->photonai->photonai-graph)
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msgpack>=1.0.0 (from distributed->photonai->photonai-graph)
#   Downloading msgpack-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl.metadata (9.1 kB)
# Collecting sortedcontainers>=2.0.5 (from distributed->photonai->photonai-graph)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0 (from distributed->photonai->photonai-graph)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.0.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from distributed->photonai->photonai-graph) (6.3.3)
# Collecting zict>=3.0.0 (from distributed->photonai->photonai-graph)
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->torch->photonai-graph) (2.1.2)
# Collecting tenacity>=6.2.0 (from plotly->photonai->photonai-graph)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prettytable->photonai->photonai-graph) (0.2.8)
# Collecting pymongo<4.0,>=3.4 (from pymodm->photonai->photonai-graph)
#   Downloading pymongo-3.13.0-cp39-cp39-macosx_10_9_universal2.whl (430 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.0/430.0 kB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting pyaml>=16.9 (from scikit-optimize->photonai->photonai-graph)
#   Downloading pyaml-23.9.7-py3-none-any.whl.metadata (11 kB)
# Collecting matplotlib>=2.0.0 (from nxt-gem->photonai-graph)
#   Downloading matplotlib-3.8.2-cp39-cp39-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=2.0.0->nxt-gem->photonai-graph)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting scipy (from photonai-graph)
#   Downloading scipy-1.11.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting patsy>=0.5.2 (from statsmodels->photonai->photonai-graph)
#   Downloading patsy-0.5.4-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy->torch->photonai-graph) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask>=2021.10.0->photonai->photonai-graph) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->photonai-graph) (3.2.2)
# Downloading GraKeL-0.1.10-cp39-cp39-macosx_10_9_x86_64.whl (719 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.9/719.9 kB 571.7 kB/s eta 0:00:00a 0:00:01
# Downloading igraph-0.11.3-cp39-abi3-macosx_10_9_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 598.2 kB/s eta 0:00:0000:0100:01
# Downloading photonai-2.4.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 910.1 kB/s eta 0:00:00a 0:00:01
# Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 1.5 MB/s eta 0:00:0000:010:010m
# Downloading Cython-3.0.6-cp39-cp39-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 1.5 MB/s eta 0:00:0000:0100:01
# Downloading dask-2023.11.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading distributed-2023.11.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading prettytable-3.9.0-py3-none-any.whl (27 kB)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading matplotlib-3.8.2-cp39-cp39-macosx_10_12_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 2.4 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.11.4-cp39-cp39-macosx_10_9_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 2.5 MB/s eta 0:00:0000:0100:01
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 1.7 MB/s eta 0:00:0000:0100:01
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading msgpack-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Downloading patsy-0.5.4-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading pyaml-23.9.7-py3-none-any.whl (23 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492022 sha256=02b6de4ce532352731062dd133064129528eca608d0df22eea493d6eac5970ca
#   Stored in directory: /Users/hidayabouchouka/Library/Caches/pip/wheels/bf/5d/6a/2e53874f7ec4e2bede522385439531fafec8fafe005b5c3d1b
# Successfully built future
# Installing collected packages: texttable, sortedcontainers, zict, xlrd, toolz, tenacity, tblib, scipy, pymongo, pydot, pyaml, prettytable, patsy, msgpack, locket, importlib-resources, igraph, future, fsspec, cython, scikit-learn, pymodm, plotly, partd, matplotlib, dgl, statsmodels, seaborn, scikit-optimize, imbalanced-learn, grakel, dask, distributed, photonai, photonai-graph
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.2
#     Uninstalling scipy-1.9.2:
#       Successfully uninstalled scipy-1.9.2
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.3
#     Uninstalling pymongo-4.3.3:
#       Successfully uninstalled pymongo-4.3.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Uninstalling scikit-learn-1.1.2:
#       Successfully uninstalled scikit-learn-1.1.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.1
#     Uninstalling matplotlib-3.6.1:
#       Successfully uninstalled matplotlib-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# motor 3.1.2 requires pymongo<5,>=4.1, but you have pymongo 3.13.0 which is incompatible.
# Successfully installed cython-3.0.6 dask-2023.11.0 dgl-1.0.0 distributed-2023.11.0 fsspec-2023.10.0 future-0.18.3 grakel-0.1.10 igraph-0.11.3 imbalanced-learn-0.11.0 importlib-resources-6.1.1 locket-1.0.0 matplotlib-3.8.2 msgpack-1.0.7 partd-1.4.1 patsy-0.5.4 photonai-2.4.0 photonai-graph-0.2.5 plotly-5.18.0 prettytable-3.9.0 pyaml-23.9.7 pydot-1.4.2 pymodm-0.4.3 pymongo-3.13.0 scikit-learn-1.3.0 scikit-optimize-0.9.0 scipy-1.11.4 seaborn-0.13.0 sortedcontainers-2.4.0 statsmodels-0.14.0 tblib-3.0.0 tenacity-8.2.3 texttable-1.7.0 toolz-0.12.0 xlrd-2.0.1 zict-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import General Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# ## GraphFactorization

# %%
# Importing necessary libraries

from gem.embedding.gf import GraphFactorization

# Creating a barbell graph with 10 fully connected nodes on each side and 4 connecting nodes
G = nx.barbell_graph(m1=10, m2=4)

# GraphFactorization algorithm parameters Initialization
gf = GraphFactorization(d=2, #Dim. of Embeddings
                        data_set=None, #No dataset to guide  the embedding process 
       	                max_iter=10000,# Max training epochs
                        eta=1*10**-4, # Learning Rate
                        regu=1.0 # Regularization Strength
                        )

# Training the algorithm to learn the node embeddings from G
gf.learn_embedding(G)

# Retrieving the computed embeddings for each node
embeddings = gf.get_embedding()
# Out:
# ./gf not found. Reverting to Python implementation. Please compile gf, place node2vec in the path and grant executable permission

# %% [markdown]
# ### Visualization

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
nx.draw(G, with_labels = True, ax=axs[0])

for x in G.nodes():
    v  = embeddings[x]
    axs[1].scatter(v[0],v[1], s=500)
    axs[1].annotate(str(x), (v[0],v[1]), fontsize=10)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.5)
# Add a title to the overall plot
fig.suptitle('Nodes Embedings Using GF method', fontweight='bold', fontsize=16)

# Add titles to subplots
axs[0].set_title('A Barbell Graph', fontweight='bold')
axs[1].set_title('GF Nodes embedings', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'GF Nodes embedings')

# %% [markdown]
# ## HOPE

# %%
# Importing necessary libraries
from gem.embedding.hope import HOPE

# Initializing HOPE with desired parameters
ghope = HOPE(d=4, #Dimension of the embedding space
             beta=0.01)

# Learning the embedding for the given graph
ghope.learn_embedding(G)

# Retrieving the embeddings generated by HOPE
embeddings = ghope.get_embedding()
# Out:
# SVD error (low rank): 0.052092

# %% [markdown]
# ### Visualization

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
nx.draw(G, with_labels = True, ax=axs[0])

for x in G.nodes():
    v  = embeddings[x]
    axs[1].scatter(v[0],v[1], s=500)
    axs[1].annotate(str(x), (v[0],v[1]), fontsize=10)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.5)
# Add a title to the overall plot
fig.suptitle('Nodes Embedings Using HOPE method', fontweight='bold', fontsize=16)

# Add titles to subplots
axs[0].set_title('A Barbell Graph', fontweight='bold')
axs[1].set_title('HOPE Nodes embedings', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'HOPE Nodes embedings')

# %% [markdown]
# # Challenges:
#
# ## Challenge 1:
# Using the  matrix of a network graph saved in the file `data/inf-USAir97.mtx`:
# - Create the graph using the follwing code:
# ```
# from scipy.io import mmread
# adj_mat = mmread("data/inf-USAir97.mtx")
# graph = nx.from_scipy_sparse_matrix(adj_mat)
# ```
#
# - Perform Nodes Embedings with the two Matrix Factorization Based embedings  Methods: Graph Factorization  and HOPE

# %%
#your solution

from scipy.io import mmread
adj_mat = mmread("data/inf-USAir97.mtx")
graph = nx.from_scipy_sparse_array(adj_mat)

# %% [markdown]
# ## 1- MF method

# %%
gf = GraphFactorization(d=2, #Dim. of Embeddings
                        data_set=None, #No dataset to guide  the embedding process 
       	                max_iter=10000,# Max training epochs
                        eta=1*10**-4, # Learning Rate
                        regu=1.0 # Regularization Strength
                        )

# Training the algorithm to learn the node embeddings from G
gf.learn_embedding(graph)

# Retrieving the computed embeddings for each node
embeddings = gf.get_embedding()
# Out:
# ./gf not found. Reverting to Python implementation. Please compile gf, place node2vec in the path and grant executable permission

# %% [markdown]
# ## Visualization

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
nx.draw(graph, with_labels = True, ax=axs[0])

for x in graph.nodes():
    v  = embeddings[x]
    axs[1].scatter(v[0],v[1], s=500)
    axs[1].annotate(str(x), (v[0],v[1]), fontsize=10)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.5)
# Add a title to the overall plot
fig.suptitle('Nodes Embedings Using HOPE method', fontweight='bold', fontsize=16)

# Add titles to subplots
axs[0].set_title('A Barbell Graph', fontweight='bold')
axs[1].set_title('HOPE Nodes embedings', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'HOPE Nodes embedings')

# %% [markdown]
# ## 2 - HOPE

# %%
from gem.embedding.hope import HOPE

# Initializing HOPE with desired parameters
hope = HOPE(d=4, #Dimension of the embedding space
             beta=0.01)

# Learning the embedding for the given graph
hope.learn_embedding(graph)

# Retrieving the embeddings generated by HOPE
embeddings = hope.get_embedding()
# Out:
# SVD error (low rank): 0.041526

# %% [markdown]
# ## Visualization

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
nx.draw(graph, with_labels = True, ax=axs[0])

for x in graph.nodes():
    v  = embeddings[x]
    axs[1].scatter(v[0],v[1], s=500)
    axs[1].annotate(str(x), (v[0],v[1]), fontsize=10)

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.5)
# Add a title to the overall plot
fig.suptitle('Nodes Embedings Using HOPE method', fontweight='bold', fontsize=16)

# Add titles to subplots
axs[0].set_title('A Barbell Graph', fontweight='bold')
axs[1].set_title('HOPE Nodes embedings', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'HOPE Nodes embedings')
